# %% [markdown]
# <a href="https://colab.research.google.com/github/samtam0714/data-analysis-google/blob/master/banking_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load dataset
dataset = pd.read_csv('./Dataset-finalproj.csv')
dataset.head()
# Out:
#         V1       V2       V3        V4  Classification
# 0 -2.25010  3.31290 -0.88369 -2.897400               1
# 1  0.26637  0.73252 -0.67891  0.035330               1
# 2  4.79650  6.98590 -1.99670 -0.350010               0
# 3  0.75736  3.02940  2.91640 -0.068117               0
# 4 -1.72630 -6.02370  5.24190  0.295240               1

# %%
ax = sns.boxplot(x="Classification", y="V1", hue="Classification", data=dataset, palette="Set3")

# %%
ax = sns.boxplot(x="Classification", y="V2", hue="Classification", data=dataset, palette="Set3")

# %%
ax = sns.boxplot(x="Classification", y="V3", hue="Classification", data=dataset, palette="Set3")

# %%
ax = sns.boxplot(x="Classification", y="V4", hue="Classification", data=dataset, palette="Set3")

# %%
sns.distplot(dataset['V1'], kde=False);
plt.axvline(0, color="k", linestyle="--");
# Out:
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.swarmplot(x='Classification', y='V1', data=dataset, 
              hue='Classification')

# %%
sns.boxplot(data=dataset)

# %%
# Large bandwidth
sns.kdeplot(dataset['V1'], shade=True, bw=.9, color="blue")

# %%
sns.FacetGrid(dataset, hue="Classification", size=5) \
   .map(plt.scatter, "V2","V3") \
   .add_legend()

# %%
g = sns.pairplot(dataset)

# %%
ax = sns.countplot(x="Classification", data=dataset)

# %%
ax = sns.regplot(x="V1", y="Classification", data=dataset, logistic=True, n_boot=500, y_jitter=.03)
# Out:
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dataset.V4)
# Out:
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# First, we'll import pandas, a data processing and CSV file I/O library
import pandas as pd
 
# We'll also import seaborn, a Python graphing library
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

# %%
dataset.plot(kind="scatter", x="V1", y="V2")

# %%
sns.FacetGrid(dataset, hue="Classification", size=5) \
   .map(plt.scatter, "V1", "V2") \
   .add_legend()

# %%
sns.boxplot(x="Classification", y="V3", data=dataset)

# %%
# One way we can extend this plot is adding a layer of individual points on top of
# it through Seaborn's striplot
# 
# We'll use jitter=True so that all the points don't fall in single vertical lines
# above the species
#
# Saving the resulting axes as ax each time causes the resulting plot to be shown
# on top of the previous axes
ax = sns.boxplot(x="V1", y="V2", data=dataset)
ax = sns.stripplot(x="Classification", y="V3", data=dataset, jitter=True, edgecolor="gray")

# %%
dataset['Classification'].value_counts()
# Out:
# 0    762
# 1    610
# Name: Classification, dtype: int64

# %%
# A final seaborn plot useful for looking at univariate relations is the kdeplot,
# which creates and visualizes a kernel density estimate of the underlying feature
sns.FacetGrid(dataset, hue="Classification", size=6) \
   .map(sns.kdeplot, "V1") \
   .add_legend()
# Out:
# C:\Users\Ys-Ta\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.pairplot(data = dataset, hue="Classification")
